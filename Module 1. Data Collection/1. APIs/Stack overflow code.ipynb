# %%
import requests
# api key
ROOT_URL = "https://api.stackexchange.com"
POSTS_ENDPOINT = "/2.3/badges?fromdate=1628553600&todate=1628640000&order=asc&max=3&sort=name&site=stackoverflow"
r = requests.get(ROOT_URL+POSTS_ENDPOINT)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'items': [{'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'bronze',
#    'badge_id': 9878,
#    'link': 'https://stackoverflow.com/badges/9878/class-file',
#    'name': '.class-file'},
#   {'badge_type': 'tag_based',
#    'award_count': 21,
#    'rank': 'silver',
#    'badge_id': 204,
#    'link': 'https://stackoverflow.com/badges/204/htaccess',
#    'name': '.htaccess'},
#   {'badge_type': 'tag_based',
#    'award_count': 64,
#    'rank': 'bronze',
#    'badge_id': 600,
#    'link': 'https://stackoverflow.com/badges/600/htaccess',
#    'name': '.htaccess'},
#   {'badge_type': 'tag_based',
#    'award_count': 5,
#    'rank': 'gold',
#    'badge_id': 2376,
#    'link': 'https://stackoverflow.com/badges/2376/htaccess',
#    'name': '.htaccess'},
#   {'badge_type': 'tag_based',
#    'award_count': 498,
#    'rank': 'silver',
#    'badge_id': 41,
#    'link': 'https://stackoverflow.com/badges/41/net',
#    'name': '.net'},
#   {'badge_type': 'tag_based',
#    'award_count': 145,
#    'rank': 'gold',
#    'badge_id': 43,
#    'link': 'https://stackoverflow.com/badges/43/net',
#    'name': '.net'},
#   {'badge_type': 'tag_based',
#    'award_count': 2275,
#    'rank': 'bronze',
#    'badge_id': 283,
#    'link': 'https://stackoverflow.com/badges/283/net',
#    'name': '.net'},
#   {'badge_type': 'tag_based',
#    'award_count': 10,
#    'rank': 'bronze',
#    'badge_id': 535,
#    'link': 'https://stackoverflow.com/badges/535/net-2-0',
#    'name': '.net-2.0'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'silver',
#    'badge_id': 1325,
#    'link': 'https://stackoverflow.com/badges/1325/net-2-0',
#    'name': '.net-2.0'},
#   {'badge_type': 'tag_based',
#    'award_count': 3,
#    'rank': 'silver',
#    'badge_id': 185,
#    'link': 'https://stackoverflow.com/badges/185/net-3-5',
#    'name': '.net-3.5'},
#   {'badge_type': 'tag_based',
#    'award_count': 15,
#    'rank': 'bronze',
#    'badge_id': 292,
#    'link': 'https://stackoverflow.com/badges/292/net-3-5',
#    'name': '.net-3.5'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'gold',
#    'badge_id': 2767,
#    'link': 'https://stackoverflow.com/badges/2767/net-3-5',
#    'name': '.net-3.5'},
#   {'badge_type': 'tag_based',
#    'award_count': 24,
#    'rank': 'bronze',
#    'badge_id': 635,
#    'link': 'https://stackoverflow.com/badges/635/net-4-0',
#    'name': '.net-4.0'},
#   {'badge_type': 'tag_based',
#    'award_count': 5,
#    'rank': 'silver',
#    'badge_id': 1067,
#    'link': 'https://stackoverflow.com/badges/1067/net-4-0',
#    'name': '.net-4.0'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'gold',
#    'badge_id': 2400,
#    'link': 'https://stackoverflow.com/badges/2400/net-4-0',
#    'name': '.net-4.0'},
#   {'badge_type': 'tag_based',
#    'award_count': 9,
#    'rank': 'bronze',
#    'badge_id': 2549,
#    'link': 'https://stackoverflow.com/badges/2549/net-4-5',
#    'name': '.net-4.5'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'silver',
#    'badge_id': 3673,
#    'link': 'https://stackoverflow.com/badges/3673/net-4-5',
#    'name': '.net-4.5'},
#   {'badge_type': 'tag_based',
#    'award_count': 2,
#    'rank': 'bronze',
#    'badge_id': 2425,
#    'link': 'https://stackoverflow.com/badges/2425/net-assembly',
#    'name': '.net-assembly'},
#   {'badge_type': 'tag_based',
#    'award_count': 70,
#    'rank': 'bronze',
#    'badge_id': 6057,
#    'link': 'https://stackoverflow.com/badges/6057/net-core',
#    'name': '.net-core'},
#   {'badge_type': 'tag_based',
#    'award_count': 15,
#    'rank': 'silver',
#    'badge_id': 6709,
#    'link': 'https://stackoverflow.com/badges/6709/net-core',
#    'name': '.net-core'},
#   {'badge_type': 'tag_based',
#    'award_count': 2,
#    'rank': 'gold',
#    'badge_id': 7823,
#    'link': 'https://stackoverflow.com/badges/7823/net-core',
#    'name': '.net-core'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'bronze',
#    'badge_id': 9961,
#    'link': 'https://stackoverflow.com/badges/9961/net-native',
#    'name': '.net-native'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'bronze',
#    'badge_id': 7262,
#    'link': 'https://stackoverflow.com/badges/7262/net-standard',
#    'name': '.net-standard'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'silver',
#    'badge_id': 8275,
#    'link': 'https://stackoverflow.com/badges/8275/net-standard',
#    'name': '.net-standard'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'bronze',
#    'badge_id': 9672,
#    'link': 'https://stackoverflow.com/badges/9672/net-standard-2-0',
#    'name': '.net-standard-2.0'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'bronze',
#    'badge_id': 5409,
#    'link': 'https://stackoverflow.com/badges/5409/2d',
#    'name': '2d'},
#   {'badge_type': 'tag_based',
#    'award_count': 1,
#    'rank': 'bronze',
#    'badge_id': 9122,
#    'link': 'https://stackoverflow.com/badges/9122/2sxc',
#    'name': '2sxc'}],
#  'has_more': False,
#  'quota_max': 300,
#  'quota_remaining': 294}

# %%
print(r.json().keys())
# Out:
# dict_keys(['items', 'has_more', 'quota_max', 'quota_remaining'])

# %%
r.json()['items'][:3]
# Out:
# [{'badge_type': 'tag_based',
#   'award_count': 1,
#   'rank': 'bronze',
#   'badge_id': 9878,
#   'link': 'https://stackoverflow.com/badges/9878/class-file',
#   'name': '.class-file'},
#  {'badge_type': 'tag_based',
#   'award_count': 21,
#   'rank': 'silver',
#   'badge_id': 204,
#   'link': 'https://stackoverflow.com/badges/204/htaccess',
#   'name': '.htaccess'},
#  {'badge_type': 'tag_based',
#   'award_count': 64,
#   'rank': 'bronze',
#   'badge_id': 600,
#   'link': 'https://stackoverflow.com/badges/600/htaccess',
#   'name': '.htaccess'}]

# %%
all_items = r.json()['items']
names = all_items.['name']
print(names)
# Out:
#   File "/tmp/ipykernel_79721/1540469259.py", line 2
#     names = all_items.['name']
#                       ^
# SyntaxError: invalid syntax

# %%
ROOT_URL = "https://api.stackexchange.com"
POSTS_ENDPOINT = "/2.3/posts?fromdate=1628035200&todate=1628640000&order=asc&min=10&sort=votes&site=stackoverflow"
r = requests.get(ROOT_URL+POSTS_ENDPOINT)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'items': [{'owner': {'account_id': 1577895,
#     'reputation': 20969,
#     'user_id': 1463922,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/3878980c7836d9e36f3a9ac100ff36a8?s=128&d=identicon&r=PG',
#     'display_name': 'PiotrNycz',
#     'link': 'https://stackoverflow.com/users/1463922/piotrnycz'},
#    'score': 10,
#    'last_edit_date': 1628690292,
#    'last_activity_date': 1628690292,
#    'creation_date': 1628260648,
#    'post_type': 'question',
#    'post_id': 68683416,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/68683416'},
#   {'owner': {'account_id': 2759852,
#     'reputation': 5110,
#     'user_id': 2376954,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d224ac3a2d1a260c5193bcf436cfdca0?s=128&d=identicon&r=PG',
#     'display_name': 'Leif &#197;strand',
#     'link': 'https://stackoverflow.com/users/2376954/leif-%c3%85strand'},
#    'score': 10,
#    'last_activity_date': 1628149216,
#    'creation_date': 1628149216,
#    'post_type': 'answer',
#    'post_id': 68662445,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68662445'},
#   {'owner': {'account_id': 6443508,
#     'reputation': 557,
#     'user_id': 10521389,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/y7Jz2.jpg?s=128&g=1',
#     'display_name': 'logjammin',
#     'link': 'https://stackoverflow.com/users/10521389/logjammin'},
#    'score': 10,
#    'last_edit_date': 1628258046,
#    'last_activity_date': 1628258046,
#    'creation_date': 1628189634,
#    'post_type': 'question',
#    'post_id': 68672119,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/68672119'},
#   {'owner': {'account_id': 6475833,
#     'reputation': 68199,
#     'user_id': 5014455,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/JTknr.png?s=128&g=1',
#     'display_name': 'juanpa.arrivillaga',
#     'link': 'https://stackoverflow.com/users/5014455/juanpa-arrivillaga'},
#    'score': 10,
#    'last_edit_date': 1628045748,
#    'last_activity_date': 1628045748,
#    'creation_date': 1628043534,
#    'post_type': 'answer',
#    'post_id': 68644651,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68644651'},
#   {'owner': {'account_id': 1508549,
#     'reputation': 4519,
#     'user_id': 2516916,
#     'user_type': 'registered',
#     'accept_rate': 79,
#     'profile_image': 'https://www.gravatar.com/avatar/90d670e62ae35e180ad6e939443cab62?s=128&d=identicon&r=PG',
#     'display_name': 'Gillespie',
#     'link': 'https://stackoverflow.com/users/2516916/gillespie'},
#    'score': 10,
#    'last_activity_date': 1628276143,
#    'creation_date': 1628194610,
#    'post_type': 'question',
#    'post_id': 68673014,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/68673014'},
#   {'owner': {'account_id': 106133,
#     'reputation': 97137,
#     'user_id': 282848,
#     'user_type': 'registered',
#     'accept_rate': 93,
#     'profile_image': 'https://www.gravatar.com/avatar/ced1d4c4fa1cd38d87553bf0e4836120?s=128&d=identicon&r=PG',
#     'display_name': 'Andreas Rejbrand',
#     'link': 'https://stackoverflow.com/users/282848/andreas-rejbrand'},
#    'score': 10,
#    'last_edit_date': 1628113262,
#    'last_activity_date': 1628113262,
#    'creation_date': 1628111565,
#    'post_type': 'answer',
#    'post_id': 68658087,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68658087'},
#   {'owner': {'account_id': 1442484,
#     'reputation': 338,
#     'user_id': 1362165,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/UU5RE.png?s=128&g=1',
#     'display_name': 'Mike123456',
#     'link': 'https://stackoverflow.com/users/1362165/mike123456'},
#    'score': 11,
#    'last_activity_date': 1628425222,
#    'creation_date': 1628425222,
#    'post_type': 'answer',
#    'post_id': 68700698,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68700698'},
#   {'owner': {'account_id': 22227990,
#     'reputation': 111,
#     'user_id': 16464661,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/36cfdf6fe9f55983f7e421dfa972dd92?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Mcrunny',
#     'link': 'https://stackoverflow.com/users/16464661/mcrunny'},
#    'score': 11,
#    'last_activity_date': 1628221846,
#    'creation_date': 1628126411,
#    'post_type': 'question',
#    'post_id': 68659554,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/68659554'},
#   {'owner': {'account_id': 3868683,
#     'reputation': 42237,
#     'user_id': 3204551,
#     'user_type': 'registered',
#     'accept_rate': 75,
#     'profile_image': 'https://www.gravatar.com/avatar/91bb06155f79d40ffecdf124deecb001?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Deduplicator',
#     'link': 'https://stackoverflow.com/users/3204551/deduplicator'},
#    'score': 11,
#    'last_activity_date': 1628175893,
#    'creation_date': 1628175893,
#    'post_type': 'answer',
#    'post_id': 68669118,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68669118'},
#   {'owner': {'account_id': 5609238,
#     'reputation': 13343,
#     'user_id': 4442671,
#     'user_type': 'registered',
#     'accept_rate': 40,
#     'profile_image': 'https://www.gravatar.com/avatar/5d17bd9f2005eead84ab432bf1b5983c?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Frank',
#     'link': 'https://stackoverflow.com/users/4442671/frank'},
#    'score': 11,
#    'last_edit_date': 1628534264,
#    'last_activity_date': 1628534264,
#    'creation_date': 1628521380,
#    'post_type': 'answer',
#    'post_id': 68714323,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68714323'},
#   {'owner': {'account_id': 19093004,
#     'reputation': 850,
#     'user_id': 13942929,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Ghx-qKsOlBkB0MfmtpjXSwZ7GvZ7uF40DAGlWJ_7w=k-s128',
#     'display_name': 'Punreach Rany',
#     'link': 'https://stackoverflow.com/users/13942929/punreach-rany'},
#    'score': 11,
#    'last_edit_date': 1628472061,
#    'last_activity_date': 1628472061,
#    'creation_date': 1628127641,
#    'post_type': 'answer',
#    'post_id': 68659648,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68659648'},
#   {'owner': {'account_id': 18926542,
#     'reputation': 185,
#     'user_id': 13809551,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/905e25f6fd194ed20eba7325b8d38a8a?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Sopeade Lanlehin',
#     'link': 'https://stackoverflow.com/users/13809551/sopeade-lanlehin'},
#    'score': 12,
#    'last_edit_date': 1628042569,
#    'last_activity_date': 1628089000,
#    'creation_date': 1628042166,
#    'post_type': 'question',
#    'post_id': 68644548,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/68644548'},
#   {'owner': {'account_id': 16644856,
#     'reputation': 121,
#     'user_id': 13653736,
#     'user_type': 'registered',
#     'profile_image': 'https://lh4.googleusercontent.com/-b10BCBV1j08/AAAAAAAAAAI/AAAAAAAAAAA/ACHi3reNlEOYE-2Kg0B65-zYxO_-Wd2DIQ/photo.jpg?sz=128',
#     'display_name': 'Андрей Пархоменко',
#     'link': 'https://stackoverflow.com/users/13653736/%d0%90%d0%bd%d0%b4%d1%80%d0%b5%d0%b9-%d0%9f%d0%b0%d1%80%d1%85%d0%be%d0%bc%d0%b5%d0%bd%d0%ba%d0%be'},
#    'score': 12,
#    'last_edit_date': 1628493748,
#    'last_activity_date': 1628493748,
#    'creation_date': 1628487342,
#    'post_type': 'answer',
#    'post_id': 68707268,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68707268'},
#   {'owner': {'account_id': 359424,
#     'reputation': 24444,
#     'user_id': 700825,
#     'user_type': 'registered',
#     'accept_rate': 72,
#     'profile_image': 'https://www.gravatar.com/avatar/6aea6e2f57f2a7b1cd6870375fbdc42f?s=128&d=identicon&r=PG',
#     'display_name': 'NoSenseEtAl',
#     'link': 'https://stackoverflow.com/users/700825/nosenseetal'},
#    'score': 12,
#    'last_edit_date': 1628518791,
#    'last_activity_date': 1628518791,
#    'creation_date': 1628515964,
#    'post_type': 'question',
#    'post_id': 68712964,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/68712964'},
#   {'owner': {'account_id': 432714,
#     'reputation': 151379,
#     'user_id': 817643,
#     'user_type': 'registered',
#     'accept_rate': 90,
#     'profile_image': 'https://www.gravatar.com/avatar/3ec3655af26685ce29823b04cb6c78d5?s=128&d=identicon&r=PG',
#     'display_name': 'StoryTeller - Unslander Monica',
#     'link': 'https://stackoverflow.com/users/817643/storyteller-unslander-monica'},
#    'score': 12,
#    'last_edit_date': 1628433985,
#    'last_activity_date': 1628433985,
#    'creation_date': 1628339525,
#    'post_type': 'answer',
#    'post_id': 68692392,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68692392'},
#   {'owner': {'account_id': 274825,
#     'reputation': 139359,
#     'user_id': 567292,
#     'user_type': 'registered',
#     'accept_rate': 84,
#     'profile_image': 'https://www.gravatar.com/avatar/b55da07dea89fa675c7e2894c77f8024?s=128&d=identicon&r=PG',
#     'display_name': 'ecatmur',
#     'link': 'https://stackoverflow.com/users/567292/ecatmur'},
#    'score': 13,
#    'last_activity_date': 1628581578,
#    'creation_date': 1628580752,
#    'post_type': 'question',
#    'post_id': 68722691,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/68722691'},
#   {'owner': {'account_id': 6816539,
#     'reputation': 58294,
#     'user_id': 5245033,
#     'user_type': 'registered',
#     'accept_rate': 53,
#     'profile_image': 'https://www.gravatar.com/avatar/6dbfd37ccb940fd2afcd49e966ad97e4?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'SergeyA',
#     'link': 'https://stackoverflow.com/users/5245033/sergeya'},
#    'score': 13,
#    'last_activity_date': 1628518538,
#    'creation_date': 1628518538,
#    'post_type': 'answer',
#    'post_id': 68713640,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68713640'},
#   {'owner': {'account_id': 2194877,
#     'reputation': 4025,
#     'user_id': 7325599,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8d601da836449a445b9f15756296061d?s=128&d=identicon&r=PG',
#     'display_name': 'Fedor',
#     'link': 'https://stackoverflow.com/users/7325599/fedor'},
#    'score': 13,
#    'last_edit_date': 1628536727,
#    'last_activity_date': 1628538754,
#    'creation_date': 1628535766,
#    'post_type': 'question',
#    'post_id': 68717308,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/68717308'},
#   {'owner': {'account_id': 380209,
#     'reputation': 386243,
#     'user_id': 734069,
#     'user_type': 'registered',
#     'accept_rate': 80,
#     'profile_image': 'https://www.gravatar.com/avatar/a356923f858fbe363dad1dc566837fc6?s=128&d=identicon&r=PG',
#     'display_name': 'Nicol Bolas',
#     'link': 'https://stackoverflow.com/users/734069/nicol-bolas'},
#    'score': 13,
#    'last_activity_date': 1628262916,
#    'creation_date': 1628262916,
#    'post_type': 'answer',
#    'post_id': 68683923,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68683923'},
#   {'owner': {'account_id': 21664607,
#     'reputation': 185,
#     'user_id': 15983216,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/da14bf02173399c946dbf4656af1e7de?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Sebastian',
#     'link': 'https://stackoverflow.com/users/15983216/sebastian'},
#    'score': 14,
#    'last_edit_date': 1628172200,
#    'last_activity_date': 1628185858,
#    'creation_date': 1628087312,
#    'post_type': 'question',
#    'post_id': 68653064,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/68653064'},
#   {'owner': {'account_id': 19093004,
#     'reputation': 850,
#     'user_id': 13942929,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Ghx-qKsOlBkB0MfmtpjXSwZ7GvZ7uF40DAGlWJ_7w=k-s128',
#     'display_name': 'Punreach Rany',
#     'link': 'https://stackoverflow.com/users/13942929/punreach-rany'},
#    'score': 14,
#    'last_edit_date': 1628172228,
#    'last_activity_date': 1628472061,
#    'creation_date': 1628126051,
#    'post_type': 'question',
#    'post_id': 68659516,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/68659516'},
#   {'owner': {'account_id': 3176925,
#     'reputation': 177912,
#     'user_id': 2684539,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/xTMIL.jpg?s=128&g=1',
#     'display_name': 'Jarod42',
#     'link': 'https://stackoverflow.com/users/2684539/jarod42'},
#    'score': 14,
#    'last_edit_date': 1628066677,
#    'last_activity_date': 1628066677,
#    'creation_date': 1628064536,
#    'post_type': 'answer',
#    'post_id': 68647638,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68647638'},
#   {'owner': {'account_id': 87230,
#     'reputation': 24238,
#     'user_id': 242042,
#     'user_type': 'registered',
#     'accept_rate': 57,
#     'profile_image': 'https://www.gravatar.com/avatar/a798a3d661375ece15776f83fbb80c2c?s=128&d=identicon&r=PG',
#     'display_name': 'Archimedes Trajano',
#     'link': 'https://stackoverflow.com/users/242042/archimedes-trajano'},
#    'score': 15,
#    'last_edit_date': 1628185782,
#    'last_activity_date': 1628185782,
#    'creation_date': 1628139503,
#    'post_type': 'answer',
#    'post_id': 68660813,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68660813'},
#   {'owner': {'account_id': 5941570,
#     'reputation': 10862,
#     'user_id': 4672588,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/edcbc85fb3b43202dab37afb2bd5281e?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'cpplearner',
#     'link': 'https://stackoverflow.com/users/4672588/cpplearner'},
#    'score': 15,
#    'last_activity_date': 1628581578,
#    'creation_date': 1628581578,
#    'post_type': 'answer',
#    'post_id': 68722862,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68722862'},
#   {'owner': {'account_id': 34433,
#     'reputation': 46093,
#     'user_id': 1400793,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/7VxVK.png?s=128&g=1',
#     'display_name': 'Paul Hankin',
#     'link': 'https://stackoverflow.com/users/1400793/paul-hankin'},
#    'score': 17,
#    'last_activity_date': 1628149084,
#    'creation_date': 1628149084,
#    'post_type': 'answer',
#    'post_id': 68662413,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68662413'},
#   {'owner': {'account_id': 4683886,
#     'reputation': 2434,
#     'user_id': 3791842,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/98W7v.jpg?s=128&g=1',
#     'display_name': 'Daniel Kleinstein',
#     'link': 'https://stackoverflow.com/users/3791842/daniel-kleinstein'},
#    'score': 17,
#    'last_edit_date': 1628541749,
#    'last_activity_date': 1628616021,
#    'creation_date': 1628540126,
#    'post_type': 'question',
#    'post_id': 68718097,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/68718097'},
#   {'owner': {'account_id': 19095065,
#     'reputation': 3053,
#     'user_id': 13944524,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/6wFrI.jpg?s=128&g=1',
#     'display_name': 'SorousH Bakhtiary',
#     'link': 'https://stackoverflow.com/users/13944524/soroush-bakhtiary'},
#    'score': 19,
#    'last_edit_date': 1628531886,
#    'last_activity_date': 1628531886,
#    'creation_date': 1628415456,
#    'post_type': 'answer',
#    'post_id': 68699503,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68699503'},
#   {'owner': {'account_id': 17047944,
#     'reputation': 2186,
#     'user_id': 12334309,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/N7ule.png?s=128&g=1',
#     'display_name': 'Nathan Pierson',
#     'link': 'https://stackoverflow.com/users/12334309/nathan-pierson'},
#    'score': 19,
#    'last_activity_date': 1628197552,
#    'creation_date': 1628197552,
#    'post_type': 'answer',
#    'post_id': 68673494,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68673494'},
#   {'owner': {'account_id': 16963287,
#     'reputation': 337,
#     'user_id': 14026460,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AAuE7mBSDXoip4z1IS6niaZqVdThdRBs8b3Q5xCRvmM5pw=k-s128',
#     'display_name': 'Manoj Ariyarathna',
#     'link': 'https://stackoverflow.com/users/14026460/manoj-ariyarathna'},
#    'score': 22,
#    'last_edit_date': 1628480584,
#    'last_activity_date': 1628618457,
#    'creation_date': 1628406254,
#    'post_type': 'question',
#    'post_id': 68698494,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/q/68698494'},
#   {'owner': {'account_id': 13414497,
#     'reputation': 20724,
#     'user_id': 10147399,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/4a6d433902192f8bb03857ae1b849d4f?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'Ayxan Haqverdili',
#     'link': 'https://stackoverflow.com/users/10147399/ayxan-haqverdili'},
#    'score': 24,
#    'last_edit_date': 1628228847,
#    'last_activity_date': 1628228847,
#    'creation_date': 1628228312,
#    'post_type': 'answer',
#    'post_id': 68676618,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/a/68676618'}],
#  'has_more': True,
#  'quota_max': 300,
#  'quota_remaining': 274}

# %%
(r.json().keys())
len(r.json()['items'])
# Out:
# 30

# %%
counter = 0
for i in range(3):
    counter =+1
    print(r.json()['items'][counter]['score'])

#for i in len(r.json()['items']):
#    print(i)
    
#    print(r.json()['items'][counter]['score'])
# Out:
# 30
# 10
# 10
# 10

# %%
r.json()['has_more']
# Out:
# False
